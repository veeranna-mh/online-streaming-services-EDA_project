# %%
import numpy as np

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
n_data=pd.read_csv('netflix_titles.csv')

# %%
n_data
# Out:
#      show_id     type                  title         director  \
# 0         s1    Movie   Dick Johnson Is Dead  Kirsten Johnson
# 1         s2  TV Show          Blood & Water              NaN
# 2         s3  TV Show              Ganglands  Julien Leclercq
# 3         s4  TV Show  Jailbirds New Orleans              NaN
# 4         s5  TV Show           Kota Factory              NaN
# ...      ...      ...                    ...              ...
# 8802   s8803    Movie                 Zodiac    David Fincher
# 8803   s8804  TV Show            Zombie Dumb              NaN
# 8804   s8805    Movie             Zombieland  Ruben Fleischer
# 8805   s8806    Movie                   Zoom     Peter Hewitt
# 8806   s8807    Movie                 Zubaan      Mozez Singh
#
#                                                    cast        country  \
# 0                                                   NaN  United States
# 1     Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...   South Africa
# ...

# %%
n_data[n_data['type']=='Movie']
# Out:
#      show_id   type                             title  \
# 0         s1  Movie              Dick Johnson Is Dead
# 6         s7  Movie  My Little Pony: A New Generation
# 7         s8  Movie                           Sankofa
# 9        s10  Movie                      The Starling
# 12       s13  Movie                      Je Suis Karl
# ...      ...    ...                               ...
# 8801   s8802  Movie                           Zinzana
# 8802   s8803  Movie                            Zodiac
# 8804   s8805  Movie                        Zombieland
# 8805   s8806  Movie                              Zoom
# 8806   s8807  Movie                            Zubaan
#
#                            director  \
# 0                   Kirsten Johnson
# 6     Robert Cullen, José Luis Ucha
# 7                      Haile Gerima
# 9                    Theodore Melfi
# 12              Christian Schwochow
# ...                             ...
# 8801                Majid Al Ansari
# ...

# %%
movies=n_data[n_data['type']=='Movie']

# %%
movies
# Out:
#      show_id   type                             title  \
# 0         s1  Movie              Dick Johnson Is Dead
# 6         s7  Movie  My Little Pony: A New Generation
# 7         s8  Movie                           Sankofa
# 9        s10  Movie                      The Starling
# 12       s13  Movie                      Je Suis Karl
# ...      ...    ...                               ...
# 8801   s8802  Movie                           Zinzana
# 8802   s8803  Movie                            Zodiac
# 8804   s8805  Movie                        Zombieland
# 8805   s8806  Movie                              Zoom
# 8806   s8807  Movie                            Zubaan
#
#                            director  \
# 0                   Kirsten Johnson
# 6     Robert Cullen, José Luis Ucha
# 7                      Haile Gerima
# 9                    Theodore Melfi
# 12              Christian Schwochow
# ...                             ...
# 8801                Majid Al Ansari
# ...

# %%
TV_shows=n_data[n_data['type']=='TV Show']

# %%
TV_shows
# Out:
#      show_id     type                  title         director  \
# 1         s2  TV Show          Blood & Water              NaN
# 2         s3  TV Show              Ganglands  Julien Leclercq
# 3         s4  TV Show  Jailbirds New Orleans              NaN
# 4         s5  TV Show           Kota Factory              NaN
# 5         s6  TV Show          Midnight Mass    Mike Flanagan
# ...      ...      ...                    ...              ...
# 8795   s8796  TV Show        Yu-Gi-Oh! Arc-V              NaN
# 8796   s8797  TV Show             Yunus Emre              NaN
# 8797   s8798  TV Show              Zak Storm              NaN
# 8800   s8801  TV Show     Zindagi Gulzar Hai              NaN
# 8803   s8804  TV Show            Zombie Dumb              NaN
#
#                                                    cast  \
# 1     Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...
# 2     Sami Bouajila, Tracy Gotoas, Samuel Jouy, Nabi...
# ...

# %%
TV_shows.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 2676 entries, 1 to 8803
# Data columns (total 12 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   show_id       2676 non-null   object
#  1   type          2676 non-null   object
#  2   title         2676 non-null   object
#  3   director      230 non-null    object
#  4   cast          2326 non-null   object
#  5   country       2285 non-null   object
#  6   date_added    2666 non-null   object
#  7   release_year  2676 non-null   int64
#  8   rating        2674 non-null   object
#  9   duration      2676 non-null   object
#  10  listed_in     2676 non-null   object
#  11  description   2676 non-null   object
# dtypes: int64(1), object(11)
# memory usage: 271.8+ KB

# %%
TV_shows.isna().sum()
# Out:
# show_id            0
# type               0
# title              0
# director        2446
# cast             350
# country          391
# date_added        10
# release_year       0
# rating             2
# duration           0
# listed_in          0
# description        0
# dtype: int64

# %% [markdown]
# # missing values
#
# ![image-5.png](attachment:image-5.png)
# ![image-3.png](attachment:image-3.png)

# %%
TV_shows
# Out:
#      show_id     type                  title         director  \
# 1         s2  TV Show          Blood & Water              NaN
# 2         s3  TV Show              Ganglands  Julien Leclercq
# 3         s4  TV Show  Jailbirds New Orleans              NaN
# 4         s5  TV Show           Kota Factory              NaN
# 5         s6  TV Show          Midnight Mass    Mike Flanagan
# ...      ...      ...                    ...              ...
# 8795   s8796  TV Show        Yu-Gi-Oh! Arc-V              NaN
# 8796   s8797  TV Show             Yunus Emre              NaN
# 8797   s8798  TV Show              Zak Storm              NaN
# 8800   s8801  TV Show     Zindagi Gulzar Hai              NaN
# 8803   s8804  TV Show            Zombie Dumb              NaN
#
#                                                    cast  \
# 1     Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...
# 2     Sami Bouajila, Tracy Gotoas, Samuel Jouy, Nabi...
# ...

# %%
t1=TV_shows[['title','director']]

# %%
t1
# Out:
#                       title         director
# 1             Blood & Water              NaN
# 2                 Ganglands  Julien Leclercq
# 3     Jailbirds New Orleans              NaN
# 4              Kota Factory              NaN
# 5             Midnight Mass    Mike Flanagan
# ...                     ...              ...
# 8795        Yu-Gi-Oh! Arc-V              NaN
# 8796             Yunus Emre              NaN
# 8797              Zak Storm              NaN
# 8800     Zindagi Gulzar Hai              NaN
# 8803            Zombie Dumb              NaN
#
# [2676 rows x 2 columns]

# %%
TV_shows['director'] = TV_shows['director'].str.split(', ')
# Out:
# C:\Users\Dell\AppData\Local\Temp\ipykernel_12272\2177744900.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   TV_shows['director'] = TV_shows['director'].str.split(', ')

# %%
TV_shows['country'] = TV_shows['country'].str.split(', ')
# Out:
# C:\Users\Dell\AppData\Local\Temp\ipykernel_12272\1403327742.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   TV_shows['country'] = TV_shows['country'].str.split(', ')

# %%
TV_shows['listed_in'] = TV_shows['listed_in'].str.split(', ')
# Out:
# C:\Users\Dell\AppData\Local\Temp\ipykernel_12272\3621196347.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   TV_shows['listed_in'] = TV_shows['listed_in'].str.split(', ')

# %%
TV_shows
# Out:
#      show_id     type                  title           director  \
# 1         s2  TV Show          Blood & Water                NaN
# 2         s3  TV Show              Ganglands  [Julien Leclercq]
# 3         s4  TV Show  Jailbirds New Orleans                NaN
# 4         s5  TV Show           Kota Factory                NaN
# 5         s6  TV Show          Midnight Mass    [Mike Flanagan]
# ...      ...      ...                    ...                ...
# 8795   s8796  TV Show        Yu-Gi-Oh! Arc-V                NaN
# 8796   s8797  TV Show             Yunus Emre                NaN
# 8797   s8798  TV Show              Zak Storm                NaN
# 8800   s8801  TV Show     Zindagi Gulzar Hai                NaN
# 8803   s8804  TV Show            Zombie Dumb                NaN
#
#                                                    cast  \
# 1     Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...
# 2     Sami Bouajila, Tracy Gotoas, Samuel Jouy, Nabi...
# ...

# %%
TV_shows['director'].unique
# Out:
# <bound method Series.unique of 1                     NaN
# 2       [Julien Leclercq]
# 3                     NaN
# 4                     NaN
# 5         [Mike Flanagan]
#               ...
# 8795                  NaN
# 8796                  NaN
# 8797                  NaN
# 8800                  NaN
# 8803                  NaN
# Name: director, Length: 2676, dtype: object>

# %%
TV_shows['director'].value_counts()
# Out:
# director
# [Alastair Fothergill]                  3
# [Rob Seidenglanz]                      2
# [Hsu Fu-chun]                          2
# [Iginio Straffi]                       2
# [Shin Won-ho]                          2
#                                       ..
# [Juliana Vicente]                      1
# [Chang Chin-jung, Chen Rong-hui]       1
# [Thierry Demaizière, Alban Teurlai]    1
# [Manolo Caro]                          1
# [Michael Cumming]                      1
# Name: count, Length: 222, dtype: int64

# %%
t2=TV_shows.explode('director')

# %%
t2
# Out:
#      show_id     type                  title         director  \
# 1         s2  TV Show          Blood & Water              NaN
# 2         s3  TV Show              Ganglands  Julien Leclercq
# 3         s4  TV Show  Jailbirds New Orleans              NaN
# 4         s5  TV Show           Kota Factory              NaN
# 5         s6  TV Show          Midnight Mass    Mike Flanagan
# ...      ...      ...                    ...              ...
# 8795   s8796  TV Show        Yu-Gi-Oh! Arc-V              NaN
# 8796   s8797  TV Show             Yunus Emre              NaN
# 8797   s8798  TV Show              Zak Storm              NaN
# 8800   s8801  TV Show     Zindagi Gulzar Hai              NaN
# 8803   s8804  TV Show            Zombie Dumb              NaN
#
#                                                    cast  \
# 1     Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...
# 2     Sami Bouajila, Tracy Gotoas, Samuel Jouy, Nabi...
# ...

# %%
t3=t2.explode('country')

# %%
t3
# Out:
#      show_id     type                  title         director  \
# 1         s2  TV Show          Blood & Water              NaN
# 2         s3  TV Show              Ganglands  Julien Leclercq
# 3         s4  TV Show  Jailbirds New Orleans              NaN
# 4         s5  TV Show           Kota Factory              NaN
# 5         s6  TV Show          Midnight Mass    Mike Flanagan
# ...      ...      ...                    ...              ...
# 8797   s8798  TV Show              Zak Storm              NaN
# 8797   s8798  TV Show              Zak Storm              NaN
# 8797   s8798  TV Show              Zak Storm              NaN
# 8800   s8801  TV Show     Zindagi Gulzar Hai              NaN
# 8803   s8804  TV Show            Zombie Dumb              NaN
#
#                                                    cast       country  \
# 1     Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...  South Africa
# 2     Sami Bouajila, Tracy Gotoas, Samuel Jouy, Nabi...           NaN
# ...

# %%
t4=t3.explode('listed_in')

# %%
t4
# Out:
#      show_id     type               title         director  \
# 1         s2  TV Show       Blood & Water              NaN
# 1         s2  TV Show       Blood & Water              NaN
# 1         s2  TV Show       Blood & Water              NaN
# 2         s3  TV Show           Ganglands  Julien Leclercq
# 2         s3  TV Show           Ganglands  Julien Leclercq
# ...      ...      ...                 ...              ...
# 8800   s8801  TV Show  Zindagi Gulzar Hai              NaN
# 8800   s8801  TV Show  Zindagi Gulzar Hai              NaN
# 8803   s8804  TV Show         Zombie Dumb              NaN
# 8803   s8804  TV Show         Zombie Dumb              NaN
# 8803   s8804  TV Show         Zombie Dumb              NaN
#
#                                                    cast       country  \
# 1     Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...  South Africa
# 1     Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...  South Africa
# ...

# %%
t4['cast'] = t4['cast'].str.split(', ')

# %%
t4.head()
# Out:
#   show_id     type          title         director  \
# 1      s2  TV Show  Blood & Water              NaN
# 1      s2  TV Show  Blood & Water              NaN
# 1      s2  TV Show  Blood & Water              NaN
# 2      s3  TV Show      Ganglands  Julien Leclercq
# 2      s3  TV Show      Ganglands  Julien Leclercq
#
#                                                 cast       country  \
# 1  [Ama Qamata, Khosi Ngema, Gail Mabalane, Thaba...  South Africa
# 1  [Ama Qamata, Khosi Ngema, Gail Mabalane, Thaba...  South Africa
# 1  [Ama Qamata, Khosi Ngema, Gail Mabalane, Thaba...  South Africa
# 2  [Sami Bouajila, Tracy Gotoas, Samuel Jouy, Nab...           NaN
# 2  [Sami Bouajila, Tracy Gotoas, Samuel Jouy, Nab...           NaN
#
#            date_added  release_year rating   duration               listed_in  \
# 1  September 24, 2021          2021  TV-MA  2 Seasons  International TV Shows
# 1  September 24, 2021          2021  TV-MA  2 Seasons               TV Dramas
# ...

# %%
t5=t4.explode('cast')

# %%
t5
# Out:
#      show_id     type               title director                cast  \
# 1         s2  TV Show       Blood & Water      NaN          Ama Qamata
# 1         s2  TV Show       Blood & Water      NaN         Khosi Ngema
# 1         s2  TV Show       Blood & Water      NaN       Gail Mabalane
# 1         s2  TV Show       Blood & Water      NaN      Thabang Molaba
# 1         s2  TV Show       Blood & Water      NaN    Dillon Windvogel
# ...      ...      ...                 ...      ...                 ...
# 8800   s8801  TV Show  Zindagi Gulzar Hai      NaN        Javed Sheikh
# 8800   s8801  TV Show  Zindagi Gulzar Hai      NaN  Hina Khawaja Bayat
# 8803   s8804  TV Show         Zombie Dumb      NaN                 NaN
# 8803   s8804  TV Show         Zombie Dumb      NaN                 NaN
# 8803   s8804  TV Show         Zombie Dumb      NaN                 NaN
#
#            country          date_added  release_year rating   duration  \
# ...

# %%
t5.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 56148 entries, 1 to 8803
# Data columns (total 12 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   show_id       56148 non-null  object
#  1   type          56148 non-null  object
#  2   title         56148 non-null  object
#  3   director      6790 non-null   object
#  4   cast          55330 non-null  object
#  5   country       50450 non-null  object
#  6   date_added    55990 non-null  object
#  7   release_year  56148 non-null  int64
#  8   rating        56090 non-null  object
#  9   duration      56148 non-null  object
#  10  listed_in     56148 non-null  object
#  11  description   56148 non-null  object
# dtypes: int64(1), object(11)
# memory usage: 5.6+ MB

# %%
t5.isna().sum()
# Out:
# show_id             0
# type                0
# title               0
# director        49358
# cast              818
# country          5698
# date_added        158
# release_year        0
# rating             58
# duration            0
# listed_in           0
# description         0
# dtype: int64

# %%
t5['director'].isna().sum()
# Out:
# 49358

# %%
t5['director'].fillna('unknown',inplace=True)

# %%
t5['director'].isna().sum()
# Out:
# 0

# %%
t5['cast'].isna().sum()
# Out:
# 818

# %%
t5['cast'].fillna('unknown',inplace=True)

# %%
t5['cast'].isna().sum()
# Out:
# 0

# %%
t5['country'].isna().sum()
# Out:
# 5698

# %%
t5['country'].fillna('unknown',inplace=True)

# %%
t5['country'].isna().sum()
# Out:
# 0

# %%
t5.isna().sum()
# Out:
# show_id           0
# type              0
# title             0
# director          0
# cast              0
# country           0
# date_added      158
# release_year      0
# rating           58
# duration          0
# listed_in         0
# description       0
# dtype: int64

# %%
# t5.dropna(inplace=True)

# %%
t5['date_added']=t5['date_added'].fillna('January 1, 1900')

# %%
t5.isna().sum()
# Out:
# show_id          0
# type             0
# title            0
# director         0
# cast             0
# country          0
# date_added       0
# release_year     0
# rating          58
# duration         0
# listed_in        0
# description      0
# dtype: int64

# %%
t5['rating']=t5['rating'].fillna(0)

# %%
t5.isna().sum()
# Out:
# show_id         0
# type            0
# title           0
# director        0
# cast            0
# country         0
# date_added      0
# release_year    0
# rating          0
# duration        0
# listed_in       0
# description     0
# dtype: int64

# %%
t5
# Out:
#      show_id     type               title director                cast  \
# 1         s2  TV Show       Blood & Water  unknown          Ama Qamata
# 1         s2  TV Show       Blood & Water  unknown         Khosi Ngema
# 1         s2  TV Show       Blood & Water  unknown       Gail Mabalane
# 1         s2  TV Show       Blood & Water  unknown      Thabang Molaba
# 1         s2  TV Show       Blood & Water  unknown    Dillon Windvogel
# ...      ...      ...                 ...      ...                 ...
# 8800   s8801  TV Show  Zindagi Gulzar Hai  unknown        Javed Sheikh
# 8800   s8801  TV Show  Zindagi Gulzar Hai  unknown  Hina Khawaja Bayat
# 8803   s8804  TV Show         Zombie Dumb  unknown             unknown
# 8803   s8804  TV Show         Zombie Dumb  unknown             unknown
# 8803   s8804  TV Show         Zombie Dumb  unknown             unknown
#
#            country          date_added  release_year rating   duration  \
# ...

# %%
t5.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 56148 entries, 1 to 8803
# Data columns (total 12 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   show_id       56148 non-null  object
#  1   type          56148 non-null  object
#  2   title         56148 non-null  object
#  3   director      56148 non-null  object
#  4   cast          56148 non-null  object
#  5   country       56148 non-null  object
#  6   date_added    56148 non-null  object
#  7   release_year  56148 non-null  int64
#  8   rating        56148 non-null  object
#  9   duration      56148 non-null  object
#  10  listed_in     56148 non-null  object
#  11  description   56148 non-null  object
# dtypes: int64(1), object(11)
# memory usage: 5.6+ MB

# %%
t5['duration']=t5['duration'].str.split(' ')

# %%
t5
# Out:
#      show_id     type               title director                cast  \
# 1         s2  TV Show       Blood & Water  unknown          Ama Qamata
# 1         s2  TV Show       Blood & Water  unknown         Khosi Ngema
# 1         s2  TV Show       Blood & Water  unknown       Gail Mabalane
# 1         s2  TV Show       Blood & Water  unknown      Thabang Molaba
# 1         s2  TV Show       Blood & Water  unknown    Dillon Windvogel
# ...      ...      ...                 ...      ...                 ...
# 8800   s8801  TV Show  Zindagi Gulzar Hai  unknown        Javed Sheikh
# 8800   s8801  TV Show  Zindagi Gulzar Hai  unknown  Hina Khawaja Bayat
# 8803   s8804  TV Show         Zombie Dumb  unknown             unknown
# 8803   s8804  TV Show         Zombie Dumb  unknown             unknown
# 8803   s8804  TV Show         Zombie Dumb  unknown             unknown
#
#            country          date_added  release_year rating      duration  \
# ...

# %%
t5['duration']=t5['duration'].apply(lambda x: x[0])

# %%
t5
# Out:
#      show_id     type               title director                cast  \
# 1         s2  TV Show       Blood & Water  unknown          Ama Qamata
# 1         s2  TV Show       Blood & Water  unknown         Khosi Ngema
# 1         s2  TV Show       Blood & Water  unknown       Gail Mabalane
# 1         s2  TV Show       Blood & Water  unknown      Thabang Molaba
# 1         s2  TV Show       Blood & Water  unknown    Dillon Windvogel
# ...      ...      ...                 ...      ...                 ...
# 8800   s8801  TV Show  Zindagi Gulzar Hai  unknown        Javed Sheikh
# 8800   s8801  TV Show  Zindagi Gulzar Hai  unknown  Hina Khawaja Bayat
# 8803   s8804  TV Show         Zombie Dumb  unknown             unknown
# 8803   s8804  TV Show         Zombie Dumb  unknown             unknown
# 8803   s8804  TV Show         Zombie Dumb  unknown             unknown
#
#            country          date_added  release_year rating duration  \
# ...

# %%
t5['duration']=t5['duration'].apply(lambda x: int(x))

# %%
t5
# Out:
#      show_id     type               title director                cast  \
# 1         s2  TV Show       Blood & Water  unknown          Ama Qamata
# 1         s2  TV Show       Blood & Water  unknown         Khosi Ngema
# 1         s2  TV Show       Blood & Water  unknown       Gail Mabalane
# 1         s2  TV Show       Blood & Water  unknown      Thabang Molaba
# 1         s2  TV Show       Blood & Water  unknown    Dillon Windvogel
# ...      ...      ...                 ...      ...                 ...
# 8800   s8801  TV Show  Zindagi Gulzar Hai  unknown        Javed Sheikh
# 8800   s8801  TV Show  Zindagi Gulzar Hai  unknown  Hina Khawaja Bayat
# 8803   s8804  TV Show         Zombie Dumb  unknown             unknown
# 8803   s8804  TV Show         Zombie Dumb  unknown             unknown
# 8803   s8804  TV Show         Zombie Dumb  unknown             unknown
#
#            country          date_added  release_year rating  duration  \
# ...

# %%
t5['duration'].mean()
# Out:
# 1.9281007337750231

# %%
t5.groupby('title')['title'].count()
# Out:
# title
# #blackAF                                7
# (Un)Well                                1
# 100 Days My Prince                     18
# 100 Humans                              6
# 100% Hotter                            12
#                                        ..
# แผนร้ายนายเจ้าเล่ห์                    12
# ​SAINT SEIYA: Knights of the Zodiac    24
# 忍者ハットリくん                                2
# 海的儿子                                   10
# 마녀사냥                                   15
# Name: title, Length: 2676, dtype: int64

# %%
duplicates=t5[t5.duplicated()]

# %%
duplicates
# Out:
# Empty DataFrame
# Columns: [show_id, type, title, director, cast, country, date_added, release_year, rating, duration, listed_in, description]
# Index: []

# %%
t6=t5.drop_duplicates()

# %%
t6.tail()
# Out:
#      show_id     type               title director                cast  \
# 8800   s8801  TV Show  Zindagi Gulzar Hai  unknown        Javed Sheikh
# 8800   s8801  TV Show  Zindagi Gulzar Hai  unknown  Hina Khawaja Bayat
# 8803   s8804  TV Show         Zombie Dumb  unknown             unknown
# 8803   s8804  TV Show         Zombie Dumb  unknown             unknown
# 8803   s8804  TV Show         Zombie Dumb  unknown             unknown
#
#        country         date_added  release_year rating  duration  \
# 8800  Pakistan  December 15, 2016          2012  TV-PG         1
# 8800  Pakistan  December 15, 2016          2012  TV-PG         1
# 8803   unknown       July 1, 2019          2018  TV-Y7         2
# 8803   unknown       July 1, 2019          2018  TV-Y7         2
# 8803   unknown       July 1, 2019          2018  TV-Y7         2
#
#             listed_in                                        description
# 8800        TV Dramas  Strong-willed, middle-class Kashaf and carefre...
# ...

# %%
# t6['date_added']=pd.to_datetime(t6['date_added'])
t6['date_added']=pd.to_datetime(t6['date_added'],format='mixed')
# t6['date_added']=pd.to_datetime(t6['date_added'],format='ISO8601')
# pd.to_datetime?

# %%
t6
# Out:
#      show_id     type               title director                cast  \
# 1         s2  TV Show       Blood & Water  unknown          Ama Qamata
# 1         s2  TV Show       Blood & Water  unknown         Khosi Ngema
# 1         s2  TV Show       Blood & Water  unknown       Gail Mabalane
# 1         s2  TV Show       Blood & Water  unknown      Thabang Molaba
# 1         s2  TV Show       Blood & Water  unknown    Dillon Windvogel
# ...      ...      ...                 ...      ...                 ...
# 8800   s8801  TV Show  Zindagi Gulzar Hai  unknown        Javed Sheikh
# 8800   s8801  TV Show  Zindagi Gulzar Hai  unknown  Hina Khawaja Bayat
# 8803   s8804  TV Show         Zombie Dumb  unknown             unknown
# 8803   s8804  TV Show         Zombie Dumb  unknown             unknown
# 8803   s8804  TV Show         Zombie Dumb  unknown             unknown
#
#            country date_added  release_year rating  duration  \
# ...

# %%
t6.groupby(['country','title'])['title'].count()
# Out:
# country    title
#            D.P.                                 8
# Argentina  Almost Happy                         9
#            Apache: The Life of Carlos Tevez    27
#            Carmel: Who Killed Maria Marta?      3
#            Creators                             6
#                                                ..
# unknown    You Are My Spring                   63
#            Zombie Dumb                          3
#            دفعة القاهرة                        12
#            แผนร้ายนายเจ้าเล่ห์                 12
#            海的儿子                                10
# Name: title, Length: 3031, dtype: int64

# %%
t7_country=t6.groupby(['country','title'])['country'].count()

# %%
# t7_country.to_excel('t7_countries.xlsx')

# %%
directors=t6[['show_id','director']].drop_duplicates(keep = 'first')['director'].value_counts()

# %%
directors
# Out:
# director
# unknown                  2446
# Alastair Fothergill         3
# Ken Burns                   3
# Iginio Straffi              2
# Gautham Vasudev Menon       2
#                          ...
# Jesse Vile                  1
# Ellena Wood                 1
# Picky Talarico              1
# Pedro Waddington            1
# Michael Cumming             1
# Name: count, Length: 300, dtype: int64

# %%
t6.groupby('cast')['show_id'].nunique().sort_values(ascending=False).head(10)
# Out:
# cast
# unknown               350
# Takahiro Sakurai       25
# Yuki Kaji              19
# Daisuke Ono            17
# Ai Kayano              17
# Junichi Suwabe         17
# Yuichi Nakamura        16
# Yoshimasa Hosoya       15
# Jun Fukuyama           15
# David Attenborough     14
# Name: show_id, dtype: int64

# %%
t6.groupby('country')['show_id'].nunique().sort_values(ascending=False).head(10)
# Out:
# country
# United States     938
# unknown           391
# United Kingdom    272
# Japan             199
# South Korea       170
# Canada            126
# France             90
# India              84
# Taiwan             70
# Australia          66
# Name: show_id, dtype: int64

# %%
t6.groupby('listed_in')['show_id'].nunique().sort_values(ascending=False).head(10)
# Out:
# listed_in
# International TV Shows    1351
# TV Dramas                  763
# TV Comedies                581
# Crime TV Shows             470
# Kids' TV                   451
# Docuseries                 395
# Romantic TV Shows          370
# Reality TV                 255
# British TV Shows           253
# Anime Series               176
# Name: show_id, dtype: int64

# %%
t6.groupby('director')['show_id'].nunique().sort_values(ascending=False).head(10)
# Out:
# director
# unknown                  2446
# Ken Burns                   3
# Alastair Fothergill         3
# Jung-ah Im                  2
# Joe Berlinger               2
# Hsu Fu-chun                 2
# Stan Lathan                 2
# Gautham Vasudev Menon       2
# Lynn Novick                 2
# Shin Won-ho                 2
# Name: show_id, dtype: int64

# %%
# t6.to_excel('t6B_clean.xlsx')

# %%
cast_data=t6.groupby('cast')['show_id'].nunique().sort_values(ascending=False)

# %%
country_data=t6.groupby('country')['show_id'].nunique().sort_values(ascending=False)

# %%
genre_data=t6.groupby('listed_in')['show_id'].nunique().sort_values(ascending=False)

# %%
director_data=t6.groupby('director')['show_id'].nunique().sort_values(ascending=False)

# %%
cast_data.head(10)
# Out:
# cast
# unknown               350
# Takahiro Sakurai       25
# Yuki Kaji              19
# Daisuke Ono            17
# Ai Kayano              17
# Junichi Suwabe         17
# Yuichi Nakamura        16
# Yoshimasa Hosoya       15
# Jun Fukuyama           15
# David Attenborough     14
# Name: show_id, dtype: int64

# %%
country_data.head(10)
# Out:
# country
# United States     938
# unknown           391
# United Kingdom    272
# Japan             199
# South Korea       170
# Canada            126
# France             90
# India              84
# Taiwan             70
# Australia          66
# Name: show_id, dtype: int64

# %%
genre_data.head(10)
# Out:
# listed_in
# International TV Shows    1351
# TV Dramas                  763
# TV Comedies                581
# Crime TV Shows             470
# Kids' TV                   451
# Docuseries                 395
# Romantic TV Shows          370
# Reality TV                 255
# British TV Shows           253
# Anime Series               176
# Name: show_id, dtype: int64

# %%
director_data.head(10)
# Out:
# director
# unknown                  2446
# Ken Burns                   3
# Alastair Fothergill         3
# Jung-ah Im                  2
# Joe Berlinger               2
# Hsu Fu-chun                 2
# Stan Lathan                 2
# Gautham Vasudev Menon       2
# Lynn Novick                 2
# Shin Won-ho                 2
# Name: show_id, dtype: int64

# %%
# cast_data.to_excel('t6B_cast_data_01.xlsx')
# country_data.to_excel('t6B_country_data_01.xlsx')
# genre_data.to_excel('t6B_genre_data_01.xlsx')
# director_data.to_excel('t6B_director_data_01.xlsx')

# %%
t_cast=cast_data.head(10)

# %%
t_country=country_data.head(10)

# %%
t_genre=genre_data.head(10)

# %%
t_director=director_data.head(10)

# %%
t_cast
# Out:
# cast
# unknown               350
# Takahiro Sakurai       25
# Yuki Kaji              19
# Daisuke Ono            17
# Ai Kayano              17
# Junichi Suwabe         17
# Yuichi Nakamura        16
# Yoshimasa Hosoya       15
# Jun Fukuyama           15
# David Attenborough     14
# Name: show_id, dtype: int64

# %%
t_cast_01=t_cast[1:]

# %%
t_cast_01
# Out:
# cast
# Takahiro Sakurai      25
# Yuki Kaji             19
# Daisuke Ono           17
# Ai Kayano             17
# Junichi Suwabe        17
# Yuichi Nakamura       16
# Yoshimasa Hosoya      15
# Jun Fukuyama          15
# David Attenborough    14
# Name: show_id, dtype: int64

# %%
plt.figure(figsize=(12,6))
plt.bar(t_cast_01.index,t_cast_01)
plt.xticks(rotation=90)
plt.show()

# %%
t_country
# Out:
# country
# United States     938
# unknown           391
# United Kingdom    272
# Japan             199
# South Korea       170
# Canada            126
# France             90
# India              84
# Taiwan             70
# Australia          66
# Name: show_id, dtype: int64

# %%
plt.figure(figsize=(12,6))
plt.bar(t_country.index,t_country)
plt.xticks(rotation=90)
plt.show()

# %%
t_genre
# Out:
# listed_in
# International TV Shows    1351
# TV Dramas                  763
# TV Comedies                581
# Crime TV Shows             470
# Kids' TV                   451
# Docuseries                 395
# Romantic TV Shows          370
# Reality TV                 255
# British TV Shows           253
# Anime Series               176
# Name: show_id, dtype: int64

# %%
plt.figure(figsize=(12,6))
plt.bar(t_genre.index,t_genre)
plt.xticks(rotation=90)
plt.show()

# %%
t_director
# Out:
# director
# unknown                  2446
# Ken Burns                   3
# Alastair Fothergill         3
# Jung-ah Im                  2
# Joe Berlinger               2
# Hsu Fu-chun                 2
# Stan Lathan                 2
# Gautham Vasudev Menon       2
# Lynn Novick                 2
# Shin Won-ho                 2
# Name: show_id, dtype: int64

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
t_director_01=t_director[1:]

# %%
t_director_01
# Out:
# director
# Ken Burns                3
# Alastair Fothergill      3
# Jung-ah Im               2
# Joe Berlinger            2
# Hsu Fu-chun              2
# Stan Lathan              2
# Gautham Vasudev Menon    2
# Lynn Novick              2
# Shin Won-ho              2
# Name: show_id, dtype: int64

# %%
plt.figure(figsize=(12,6))
plt.bar(t_director_01.index,t_director_01)
plt.xticks(rotation=90)
plt.show()
